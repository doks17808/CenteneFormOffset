# %%
import pdfplumber

# %%
pdf = pdfplumber.open(r'C:\Users\dso1222\Documents\TextRecognition\PDF\HealthClaim.pdf')
page = pdf.pages[0]
page.extract_tables()
# Out:
# []

# %%
page_im = page.to_image()
page_im.reset().debug_tablefinder()

# %%
print(page.objects)
# Out:
# {'figure': [{'name': 'XIPLAYER0', 'x0': Decimal('0'), 'y0': Decimal('-1.440'), 'x1': Decimal('612'), 'y1': Decimal('793.440'), 'width': Decimal('612'), 'height': Decimal('794.880'), 'object_type': 'figure', 'page_number': 1, 'top': Decimal('-1.440'), 'bottom': Decimal('793.440'), 'doctop': Decimal('-1.440')}, {'name': 'XIPLAYER_CM1', 'x0': Decimal('28.800'), 'y0': Decimal('240.480'), 'x1': Decimal('593.640'), 'y1': Decimal('772.200'), 'width': Decimal('564.840'), 'height': Decimal('531.720'), 'object_type': 'figure', 'page_number': 1, 'top': Decimal('19.800'), 'bottom': Decimal('551.520'), 'doctop': Decimal('19.800')}, {'name': 'XIPLAYER_CM2', 'x0': Decimal('43.200'), 'y0': Decimal('56.160'), 'x1': Decimal('572.040'), 'y1': Decimal('708.120'), 'width': Decimal('528.840'), 'height': Decimal('651.960'), 'object_type': 'figure', 'page_number': 1, 'top': Decimal('83.880'), 'bottom': Decimal('735.840'), 'doctop': Decimal('83.880')}, {'name': 'XIPLAYER_CM3', 'x0': Decimal('449.280'), 'y0':
# ...

# %%
print(pdf.pages)
# Out:
# [<pdfplumber.page.Page object at 0x00000250E4EF50B8>, <pdfplumber.page.Page object at 0x00000250E4EF5710>, <pdfplumber.page.Page object at 0x00000250E4EF5D68>, <pdfplumber.page.Page object at 0x00000250E4EFA588>, <pdfplumber.page.Page object at 0x00000250E4EFAC18>, <pdfplumber.page.Page object at 0x00000250E4EFD400>, <pdfplumber.page.Page object at 0x00000250E4EFDA58>, <pdfplumber.page.Page object at 0x00000250E4EFDF60>, <pdfplumber.page.Page object at 0x00000250E4F03550>, <pdfplumber.page.Page object at 0x00000250E4F03D68>, <pdfplumber.page.Page object at 0x00000250E4F062E8>]

# %%
pdf.metadata
# Out:
# {'CreationDate': "D:20191114130038-06'00'",
#  'Creator': 'Xerox WorkCentre 7855',
#  'Producer': 'Xerox WorkCentre 7855'}
